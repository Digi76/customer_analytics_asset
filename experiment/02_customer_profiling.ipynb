# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_excel(r'C:\D\Client\Debasishda\for_profiling_vDC4.xlsx')
df = pd.read_excel(r'C:\Users\DebasishGuha\DG\Personal\MTech\Sem4\Project\work\DataFiles\cluster_output\for_profiling_v1.5.xlsx',sheet_name='Data')

# %%
df.head()
# Out:
#    ClusterId  CUSTOMER_ID    INCOME_LEVEL    INCOME_MODI    SOCIAL_CLASS_MODI  \
# 0          0          920   Above 100,000  136884.970328          Upper class
# 1          0          713   Above 100,000  110091.810541   Upper middle class
# 2          0          978   Above 100,000  146193.646141  Lower middle class
# 3          0          350   Above 100,000  141385.361125   Upper middle class
# 4          0           67  75,000-100,000   80914.737658         Lower class
#
#   EDUCATION_BIN_MODI AGE_BIN  AGE
# 0                 PG     <20   69
# 1                 PG     <20   25
# 2                 PG     <20   74
# 3                 PG     <20   47
# 4                 PG     <20   66

# %%
df_summ = df.groupby(['ClusterId','EDUCATION_BIN_MODI']).agg({'CUSTOMER_ID':'count'})
df_summ = df_summ.groupby(['ClusterId','EDUCATION_BIN_MODI']).agg({'CUSTOMER_ID': 'sum'})
# df_summ = df_summ.groupby(level=0).apply(lambda x: x / float(x.sum()))
# df_summ = df_summ.rename(columns={'CUSTOMER_ID':'pct'})
df_summ = df_summ.rename(columns={'CUSTOMER_ID':'cnt'})
df_summ = df_summ.reset_index()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = df[df.ClusterId == 0]
sns.distplot(df1[['INCOME_MODI']], hist=True, label="Cluster 0: Income", color = 'green', bins = 100)
plt.xlim(0, 200000)
plt.legend(loc="upper right")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\payroll_classification\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1 = df[df.ClusterId == 1]
sns.distplot(df1[['INCOME_MODI']], hist=True, label="Cluster 1: Income", color = 'blue', bins = 100)
plt.xlim(0, 200000)
plt.legend(loc="upper right")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\payroll_classification\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1 = df[df.ClusterId == 2]
sns.distplot(df1[['INCOME_MODI']], hist=True, label="Cluster 2: Income", color = 'orange', bins = 100)
plt.xlim(0, 200000)
plt.legend(loc="upper right")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\payroll_classification\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1 = df[df.ClusterId == 0]
sns.distplot(df1[['AGE']], hist=True, label="Cluster 0: Age", color = 'green', bins = 20)
plt.xlim(0, 100)
plt.legend(loc="upper right")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\payroll_classification\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1 = df[df.ClusterId == 1]
sns.distplot(df1[['AGE']], hist=True, label="Cluster 1: Age", color = 'blue', bins = 20)
plt.xlim(0, 100)
plt.legend(loc="upper right")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\payroll_classification\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1 = df[df.ClusterId == 2]
sns.distplot(df1[['AGE']], hist=True, label="Cluster 2: Age", color = 'orange', bins = 20)
plt.xlim(0, 100)
plt.legend(loc="upper right")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\payroll_classification\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
