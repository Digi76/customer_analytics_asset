# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def plot_cat_var(explore_col):
    target_col = 'ACCEPT_INDICATOR'

    rr_overall = 29

    df = pd.read_csv(path + file)
    df_size = df.shape[0]

    df_count = df[explore_col].value_counts().reset_index()
    df_count.rename(columns={explore_col: 'count', 'index': explore_col}, inplace=True)
    df_count['Coverage%'] = (df_count['count'] / df_size) * 100

    df_grp = df.groupby(explore_col)[target_col].sum().reset_index()

    df_final = pd.merge(df_count, df_grp, on=explore_col, how='inner')
    df_final['Response Rate%'] = (df_final[target_col] / df_final['count']) * 100
    df_final.drop(['count', target_col], 1, inplace=True)
    df_final.sort_values(explore_col, inplace=True)
    df_final['RR_Overall%'] = rr_overall

    # create figure and axis objects with subplots()
    fig, ax = plt.subplots()
    # make a plot
    # ax.plot(df_final[explore_col], df_final['Coverage%'], color="red", marker="o")
    ax.bar(df_final[explore_col], df_final['Coverage%'], color="b", width=0.25, label='Coverage%')
    # set x-axis label
    ax.set_xlabel(explore_col, fontsize=14)
    # set y-axis label
    ax.set_ylabel("Coverage%", color="black", fontsize=14)
    
    '''
    # twin object for two different y-axis on the sample plot
    ax2 = ax.twinx()
    # make a plot with different y-axis using second axis object
    ax.plot(df_final[explore_col], df_final['Response Rate%'], color="red", marker="o", label='Response Rate%')
    ax.plot(df_final[explore_col], df_final['RR_Overall%'], color="green", linestyle='dashed', label='RR_Overall%')
    ax2.set_ylabel('Response Rate%', color="black", fontsize=14)
    '''
    ax.legend()
    plt.show()

# %%
if __name__ == '__main__':

    path = 'C:/project/DG_thesis/'
    path = 'C:/Users/DebasishGuha/DG/Personal/MTech/Sem4/Project/work/'
    file = 'EU_OFFER_PROPENSITY_VIEW_new.csv'

    col_list = ['EDUCATION_ID', 'LIFESTYLE_CATEGORY_ID']

    col_list = ['EDUCATION_ID', 'LIFESTYLE_CATEGORY_ID', 'FAMILY_CYCLE_ID', 'SOCIAL_CLASS_ID', 'HOUSE_PROPERTY_ID',
                'AGE_GROUP_ID', 'INCOME_LEVEL_ID', 'BULDING_TYPE_ID', 'BUILDING_VOLUME_LEVEL']

    for explore_col in col_list:
        plot_cat_var(explore_col)

# %%
path = 'C:/Users/DebasishGuha/DG/Personal/MTech/Sem4/Project/work/DataFiles/'
file_nm = 'Cust_single_view.csv'
df_cust_view = pd.read_csv(path+file_nm)

# %%
df_cust_view[['TOTAL_USAGE_SUM','TOTAL_USAGE_MEAN','MIN_DAILY_USAGE_MEAN','MIN_DAILY_USAGE_MIN','MIN_DAILY_USAGE_Max','MAX_DAILY_USAGE_MEAN','MAX_DAILY_USAGE_MIN','MAX_DAILY_USAGE_Max','CURRENT_RATE_BILL_AMOUNT_SUM','CURRENT_RATE_BILL_AMOUNT_MEAN','PROFIT_SUM','PROFIT_MEAN','AGENT_ID','MEAN_TM_RPR','NBR_AR_UPGR','NBR_CPLN_OPN','NBR_CPLN_CLS']].head()
# Out:
#    TOTAL_USAGE_SUM  TOTAL_USAGE_MEAN  MIN_DAILY_USAGE_MEAN  \
# 0          5055.71        421.309167             11.357500
# 1          8636.82        719.735000             19.279167
# 2         11454.37        954.530833             21.292500
# 3          5668.38        472.365000             12.846667
# 4          7499.15        624.929167             13.987500
#
#    MIN_DAILY_USAGE_MIN  MIN_DAILY_USAGE_Max  MAX_DAILY_USAGE_MEAN  \
# 0                10.86                12.62             17.482500
# 1                18.30                21.74             30.110833
# 2                20.84                22.34             46.115833
# 3                12.52                13.48             19.254167
# 4                13.20                16.03             28.488333
#
#    MAX_DAILY_USAGE_MIN  MAX_DAILY_USAGE_Max  CURRENT_RATE_BILL_AMOUNT_SUM  \
# 0                15.59                20.09                         926.7
# ...

# %%
#df_cust_view[['TOTAL_USAGE_SUM','TOTAL_USAGE_MEAN','MIN_DAILY_USAGE_MEAN','MIN_DAILY_USAGE_MIN','MIN_DAILY_USAGE_Max','MAX_DAILY_USAGE_MEAN','MAX_DAILY_USAGE_MIN','MAX_DAILY_USAGE_Max','CURRENT_RATE_BILL_AMOUNT_SUM','CURRENT_RATE_BILL_AMOUNT_MEAN','PROFIT_SUM','PROFIT_MEAN','AGENT_ID','MEAN_TM_RPR','NBR_AR_UPGR','NBR_CPLN_OPN','NBR_CPLN_CLS']].boxplot()
df_cust_view[['TOTAL_USAGE_MEAN','MIN_DAILY_USAGE_MEAN','MIN_DAILY_USAGE_MIN','MIN_DAILY_USAGE_Max','MAX_DAILY_USAGE_MEAN','MAX_DAILY_USAGE_MIN','MAX_DAILY_USAGE_Max','CURRENT_RATE_BILL_AMOUNT_SUM','CURRENT_RATE_BILL_AMOUNT_MEAN','PROFIT_SUM','PROFIT_MEAN','AGENT_ID','MEAN_TM_RPR','NBR_AR_UPGR','NBR_CPLN_OPN','NBR_CPLN_CLS']].boxplot()
# Out:
# <AxesSubplot:>

# %%
cont_col_list = ['TOTAL_USAGE_MEAN','MIN_DAILY_USAGE_MEAN','MIN_DAILY_USAGE_MIN','MIN_DAILY_USAGE_Max','MAX_DAILY_USAGE_MEAN','MAX_DAILY_USAGE_MIN','MAX_DAILY_USAGE_Max','CURRENT_RATE_BILL_AMOUNT_SUM','CURRENT_RATE_BILL_AMOUNT_MEAN','PROFIT_SUM','PROFIT_MEAN','MEAN_TM_RPR','NBR_AR_UPGR','NBR_CPLN_OPN','NBR_CPLN_CLS']

cont_col_list = ['MIN_DAILY_USAGE_MEAN','MIN_DAILY_USAGE_MIN','MIN_DAILY_USAGE_Max','MAX_DAILY_USAGE_MEAN','MAX_DAILY_USAGE_MIN','MAX_DAILY_USAGE_Max','CURRENT_RATE_BILL_AMOUNT_MEAN','PROFIT_SUM','PROFIT_MEAN','MEAN_TM_RPR','NBR_AR_UPGR','NBR_CPLN_OPN','NBR_CPLN_CLS']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#df = pd.DataFrame(data = np.random.random(size=(4,4)), columns = ['A','B','C','D'])
plt.xticks(rotation=90)
sns.boxplot(x="variable", y="value", data=pd.melt(df_cust_view[cont_col_list]))

plt.show()

# %%
df = pd.read_csv('C:/Users/DebasishGuha/DG/Personal/MTech/Sem4/Project/work/DataFiles/CST_BILLING_DETAILS.csv')

# %%
df.head()
# Out:
#    CST_BILLING_ID  CUSTOMER_ID  RATE_ID  CURRENT_RATE_ID  BILLING_DATE  \
# 0               1            1        5               10      20120604
# 1               2            1       10               10      20120604
# 2               3            2       14               16      20120601
# 3               4            2       16               16      20120601
# 4               5            3        5                5      20120626
#
#   BILLING_MONTH  BILLING_YEAR  BILLING_MONTH_NO  CURRENT_RATE_BILL_AMOUNT  \
# 0        12-Jun          2012                 6                      84.6
# 1        12-Jun          2012                 6                      84.1
# 2        12-Jun          2012                 6                     144.0
# 3        12-Jun          2012                 6                     159.0
# 4        12-Jun          2012                 6                     201.0
#
#    CALCULATED_BILL_AMOUNT  IS_CURRENT  PROFIT  RECOMMEND_CHANGE
# ...

# %%
df[['CURRENT_RATE_BILL_AMOUNT','CALCULATED_BILL_AMOUNT']].boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="variable", y="value", data=pd.melt(df[['CURRENT_RATE_BILL_AMOUNT','CALCULATED_BILL_AMOUNT']]))

plt.show()

# %%
df = pd.read_csv('C:/Users/DebasishGuha/DG/Personal/MTech/Sem4/Project/work/DataFiles/INTERVAL_USAGE_DAILY.csv')

# %%
df.head()
# Out:
#    RATE_ID  LOCATION_ID  CUSTOMER_ID  ACCOUNT_ID  SUBSTATION_ID  METER_ID  \
# 0        5        40928          459         879         242025       459
# 1        5        40928          459         879         242025       459
# 2        5        40928          459         879         242025       459
# 3        5        40928          459         879         242025       459
# 4        5        40928          459         879         242025       459
#
#    USAGE_DATE  TOTAL_USAGE  MIN_HOURLY_USAGE  MIN_USAGE_HOUR  \
# 0    20120502        15.20              0.31               1
# 1    20120503        15.86              0.33               2
# 2    20120504        16.74              0.33               2
# 3    20120505        12.90              0.27               1
# 4    20120506        10.95              0.26               5
#
#    MAX_HOURLY_USAGE  MAX_USAGE_HOUR  USAGE_KIND  USAGE_MULTIPLIER  \
# 0              1.24              20         NaN              1000
# ...

# %%
plt.xticks(rotation=90)

cols = ['TOTAL_USAGE','MIN_HOURLY_USAGE','MIN_USAGE_HOUR','MAX_HOURLY_USAGE','MAX_USAGE_HOUR']
sns.boxplot(x="variable", y="value", data=pd.melt(df[cols]))

plt.show()

# %%
df = pd.read_csv('C:/Users/DebasishGuha/DG/Personal/MTech/Sem4/Project/work/DataFiles/CST_COMPLAINT.csv')

# %%
df.head()
# Out:
#    CUSTOMER_ID  AGENT_ID  MEAN_TM_RPR  NBR_AR_UPGR  NBR_CPLN_OPN  NBR_CPLN_CLS
# 0            1         1         2.48     5.417033             1             0
# 1            2         2         2.91     2.151106             0             1
# 2            3         3         2.33     5.496972             1             1
# 3            4         4         3.13     2.285748             0             1
# 4            5         5         3.09     2.063996             0             1

# %%
plt.xticks(rotation=90)

cols = ['MEAN_TM_RPR','NBR_AR_UPGR','NBR_CPLN_OPN','NBR_CPLN_CLS']
sns.boxplot(x="variable", y="value", data=pd.melt(df[cols]))

plt.show()

# %%
import datetime

# %%
time1 = datetime.datetime.now()

# %%
time2 = datetime.datetime.now()

# %%
(time2 - time1).seconds
# Out:
# 9

# %%
print(datetime.timedelta(seconds=(time2 - time1).seconds))
# Out:
# 0:00:09
